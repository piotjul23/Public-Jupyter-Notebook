# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Julian Piotraszewski**
# Student

# %% [markdown]
# *I am interested in Data Science because I am often a very analytical thinker. On top of that, I want to be in some industry related to tech.*

# %% [markdown]
# ### The code in the following cell will add together the two numbers and display the result

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# 1. This is an ordered list.
# 2. ~~Strikethrough~~
# 3. > This is a blockquote.
